# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Image Retrieval'
# !ls
# Out:
# /content/drive/MyDrive/Image Retrieval
#  augmentation			  paper
#  augmentation.ipynb		  reconstruction
#  binary_scenario		  search.py
#  checkpoint			  subclass
#  core				  train_auto_encoder_magnification.ipynb
#  cuda_10.1.243_426.00_win10.exe   train_auto_encoder.py
# 'data test splitting.ipynb'	  training_1
#  index_images.ipynb		  training_1.h5
#  original			  training_1.json

# %%
import matplotlib
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import json

# %%
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import numpy as np

# %%
class ConvAutoEncoder:
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):
        input_shape = (height, width, depth)
        channel_dim = -1
        inputs = Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(alpha=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='enc_filter_'+str(f))(x)

        volume_size = K.int_shape(x)
        x = Flatten()(x)
        # Latent layer
        latent = Dense(latent_dim, name="encoded")(x)

        # Decoder layer
        x = Dense(np.prod(volume_size[1:]))(latent)
        x = Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)

        # Reverse on decoder
        for f in filters[::-1]:
            x = Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(alpha=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='dec_filter_'+str(f))(x)

        x = Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = Activation("sigmoid", name="decoded")(x)

        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %%
def visualize_predictions(_decoded, gt, samples=10):
    outputs = None
    for i in range(0, samples):
        original = (gt[i] * 255).astype("uint8")
        recon = (_decoded[i] * 255).astype("uint8")
        output = np.hstack([original, recon])
        outputs = output if outputs is None else np.vstack([outputs, output])
    return outputs

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
IMAGE_SIZE = (256, 256)
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
print("[INFO] indexing file images BreaKHis dataset...")
using_magnification = '400X'
base_dataset = "binary_scenario"
class_dir = ['benign', 'malignant']
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, using_magnification ,class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))
# Out:
# [INFO] indexing file images BreaKHis dataset...

# %%
print("[INFO] load images BreaKHis dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] load images BreaKHis dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
print("[INFO] building auto encoder...")
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
auto_encoder.compile(loss="mse", optimizer=opt)
auto_encoder.summary()
# Out:
# [INFO] building auto encoder...
# Model: "auto_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 128)     3584
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128, 128, 128)     0
# _________________________________________________________________
# enc_filter_128 (BatchNormali (None, 128, 128, 128)     512
# _________________________________________________________________
# flatten (Flatten)            (None, 2097152)           0
# _________________________________________________________________
# encoded (Dense)              (None, 48)                100663344
# _________________________________________________________________
# dense (Dense)                (None, 2097152)           102760448
# _________________________________________________________________
# reshape (Reshape)            (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 256, 256, 128)     147584
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256, 256, 128)     0
# _________________________________________________________________
# dec_filter_128 (BatchNormali (None, 256, 256, 128)     512
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 256, 256, 3)       3459
# _________________________________________________________________
# decoded (Activation)         (None, 256, 256, 3)       0
# =================================================================
# Total params: 203,579,443
# Trainable params: 203,578,931
# Non-trainable params: 512
# _________________________________________________________________

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = auto_encoder.fit(
    train_x, train_x,
    shuffle=True,
    validation_data=(val_x, val_x),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback],
    batch_size=BS)
# Out:
# [INFO] training auto encoder...
# Epoch 1/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0559
# Epoch 00001: val_loss improved from inf to 0.02453, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 50s 1s/step - loss: 0.0559 - val_loss: 0.0245
# Epoch 2/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0248
# Epoch 00002: val_loss improved from 0.02453 to 0.02388, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 61s 1s/step - loss: 0.0248 - val_loss: 0.0239
# Epoch 3/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0199
# Epoch 00003: val_loss improved from 0.02388 to 0.02344, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 59s 1s/step - loss: 0.0199 - val_loss: 0.0234
# Epoch 4/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0171
# Epoch 00004: val_loss did not improve from 0.02344
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0171 - val_loss: 0.0236
# Epoch 5/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 00005: val_loss did not improve from 0.02344
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0162 - val_loss: 0.0259
# Epoch 6/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 00006: val_loss did not improve from 0.02344
# 47/47 [==============================] - 13s 286ms/step - loss: 0.0155 - val_loss: 0.0295
# Epoch 7/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 00007: val_loss did not improve from 0.02344
# 47/47 [==============================] - 14s 287ms/step - loss: 0.0152 - val_loss: 0.0281
# Epoch 8/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0147
# Epoch 00008: val_loss did not improve from 0.02344
# 47/47 [==============================] - 14s 287ms/step - loss: 0.0147 - val_loss: 0.0258
# Epoch 9/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 00009: val_loss did not improve from 0.02344
# 47/47 [==============================] - 14s 287ms/step - loss: 0.0140 - val_loss: 0.0251
# Epoch 10/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 00010: val_loss improved from 0.02344 to 0.02095, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 47s 1s/step - loss: 0.0138 - val_loss: 0.0209
# Epoch 11/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 00011: val_loss improved from 0.02095 to 0.01838, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 65s 1s/step - loss: 0.0133 - val_loss: 0.0184
# Epoch 12/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 00012: val_loss improved from 0.01838 to 0.01714, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 58s 1s/step - loss: 0.0130 - val_loss: 0.0171
# Epoch 13/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 00013: val_loss improved from 0.01714 to 0.01491, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 65s 1s/step - loss: 0.0126 - val_loss: 0.0149
# Epoch 14/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0122
# Epoch 00014: val_loss did not improve from 0.01491
# 47/47 [==============================] - 14s 292ms/step - loss: 0.0122 - val_loss: 0.0150
# Epoch 15/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0121
# Epoch 00015: val_loss improved from 0.01491 to 0.01475, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 80s 2s/step - loss: 0.0121 - val_loss: 0.0148
# Epoch 16/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0122
# Epoch 00016: val_loss did not improve from 0.01475
# 47/47 [==============================] - 14s 289ms/step - loss: 0.0122 - val_loss: 0.0172
# Epoch 17/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0112
# Epoch 00017: val_loss improved from 0.01475 to 0.01468, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 50s 1s/step - loss: 0.0112 - val_loss: 0.0147
# Epoch 18/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 00018: val_loss improved from 0.01468 to 0.01360, saving model to training_1/cp.ckpt
# 47/47 [==============================] - 64s 1s/step - loss: 0.0109 - val_loss: 0.0136
# Epoch 19/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0106
# Epoch 00019: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 289ms/step - loss: 0.0106 - val_loss: 0.0141
# Epoch 20/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0103
# Epoch 00020: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 287ms/step - loss: 0.0103 - val_loss: 0.0144
# Epoch 21/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0098
# Epoch 00021: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 289ms/step - loss: 0.0098 - val_loss: 0.0140
# Epoch 22/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0099
# Epoch 00022: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0099 - val_loss: 0.0145
# Epoch 23/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0092
# Epoch 00023: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0092 - val_loss: 0.0145
# Epoch 24/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0088
# Epoch 00024: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0088 - val_loss: 0.0145
# Epoch 25/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 00025: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0086 - val_loss: 0.0154
# Epoch 26/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 00026: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 287ms/step - loss: 0.0080 - val_loss: 0.0145
# Epoch 27/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0077
# Epoch 00027: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0077 - val_loss: 0.0160
# Epoch 28/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 00028: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0078 - val_loss: 0.0193
# Epoch 29/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 00029: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0072 - val_loss: 0.0159
# Epoch 30/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0066
# Epoch 00030: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 288ms/step - loss: 0.0066 - val_loss: 0.0155
# Epoch 31/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 00031: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 287ms/step - loss: 0.0063 - val_loss: 0.0172
# Epoch 32/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0064
# Epoch 00032: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 286ms/step - loss: 0.0064 - val_loss: 0.0162
# Epoch 33/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00033: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 286ms/step - loss: 0.0059 - val_loss: 0.0171
# Epoch 34/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0056
# Epoch 00034: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 286ms/step - loss: 0.0056 - val_loss: 0.0164
# Epoch 35/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0058
# Epoch 00035: val_loss did not improve from 0.01360
# 47/47 [==============================] - 14s 287ms/step - loss: 0.0058 - val_loss: 0.0163
# Epoch 36/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00036: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 287ms/step - loss: 0.0054 - val_loss: 0.0158
# Epoch 37/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 00037: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 285ms/step - loss: 0.0050 - val_loss: 0.0169
# Epoch 38/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 00038: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 285ms/step - loss: 0.0053 - val_loss: 0.0164
# Epoch 39/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0054
# Epoch 00039: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 285ms/step - loss: 0.0054 - val_loss: 0.0166
# Epoch 40/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 00040: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 284ms/step - loss: 0.0047 - val_loss: 0.0165
# Epoch 41/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00041: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 286ms/step - loss: 0.0044 - val_loss: 0.0168
# Epoch 42/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00042: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 285ms/step - loss: 0.0044 - val_loss: 0.0172
# Epoch 43/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0047
# Epoch 00043: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 284ms/step - loss: 0.0047 - val_loss: 0.0171
# Epoch 44/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0044
# Epoch 00044: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 283ms/step - loss: 0.0044 - val_loss: 0.0167
# Epoch 45/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00045: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 285ms/step - loss: 0.0039 - val_loss: 0.0174
# Epoch 46/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 00046: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 285ms/step - loss: 0.0039 - val_loss: 0.0166
# Epoch 47/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0037
# Epoch 00047: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 284ms/step - loss: 0.0037 - val_loss: 0.0162
# Epoch 48/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0035
# Epoch 00048: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 285ms/step - loss: 0.0035 - val_loss: 0.0164
# Epoch 49/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00049: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 284ms/step - loss: 0.0033 - val_loss: 0.0164
# Epoch 50/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0033
# Epoch 00050: val_loss did not improve from 0.01360
# 47/47 [==============================] - 13s 284ms/step - loss: 0.0033 - val_loss: 0.0165

# %%
print("[INFO] making predictions...")
decoded = auto_encoder.predict(val_x)
vis = visualize_predictions(decoded, val_x)
image_example_path = "reconstruction"
cv2.imwrite(os.path.join(image_example_path,"recon_vis.png"), vis)
N = np.arange(0, EPOCHS)
plt.figure(figsize=(15,7))
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO] making predictions...

# %%
with open('training_1.json', 'w') as f:
    json.dump(H.history, f)

# %%
auto_encoder.save('training_1.h5')
