# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Image Retrieval'
# !ls
# Out:
# /content/drive/MyDrive/Image Retrieval
#  augmentation.ipynb
#  binary_scenario
#  binary_scenario_augmented_400X
#  checkpoint
#  citra_split.ipynb
#  core
# 'data test splitting.ipynb'
#  extract_feature_binary.ipynb
#  extract_feature_subclass.ipynb
#  index_images.ipynb
#  original
#  paper
#  reconstruction
#  retrieval_1_100X.ipynb
#  retrieval_1_200X.ipynb
#  retrieval_1_200X_subclass.ipynb
#  retrieval_1_400X.ipynb
#  retrieval_1_400X_subclass.ipynb
#  retrieval.ipynb
#  subclass_400
#  subclass_scenario
#  train_auto_encoder_magnification_1_100.ipynb
#  train_auto_encoder_magnification_1_200.ipynb
#  train_auto_encoder_magnification_1_400.ipynb
#  train_auto_encoder_subclass_1_200.ipynb
#  train_auto_encoder_subclass_1_400.ipynb
#  training_1_200
#  training_1_200.h5
#  training_1_200.json
#  training_1_200_subclass
#  training_1_200_subclass.h5
#  training_1_200_subclass.json
#  training_1_400
#  training_1_400.json
#  training_1_400_subclass
#  training_1_400_subclass.h5
#  training_1_400_subclass.json
#  training_1.h5
#  training_1_indexed_200.json
#  training_1_indexed_200_subclass.json
#  training_1_indexed_400.json
#  training_1_indexed_400_subclass.json
#  training_1.json

# %%
import matplotlib
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint 
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import json

# %%
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import numpy as np

# %%
class ConvAutoEncoder:
    @staticmethod
    def build(width, height, depth, filters=(128,), latent_dim=48):
        input_shape = (height, width, depth)
        channel_dim = -1
        inputs = Input(shape=input_shape)
        x = inputs
        # Encoder layer
        for f in filters:
            x = Conv2D(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(alpha=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='enc_filter_'+str(f))(x)

        volume_size = K.int_shape(x)
        x = Flatten()(x)
        # Latent layer
        latent = Dense(latent_dim, name="encoded")(x)

        # Decoder layer
        x = Dense(np.prod(volume_size[1:]))(latent)
        x = Reshape((volume_size[1], volume_size[2], volume_size[3]))(x)

        # Reverse on decoder
        for f in filters[::-1]:
            x = Conv2DTranspose(f, (3, 3), strides=2, padding='same')(x)
            x = LeakyReLU(alpha=0.2)(x)
            x = BatchNormalization(axis=channel_dim, name='dec_filter_'+str(f))(x)

        x = Conv2DTranspose(depth, (3, 3), padding="same")(x)
        outputs = Activation("sigmoid", name="decoded")(x)

        auto_encoder = Model(inputs, outputs, name="auto_encoder")
        return auto_encoder

# %%
def visualize_predictions(_decoded, gt, samples=10):
    outputs = None
    for i in range(0, samples):
        original = (gt[i] * 255).astype("uint8")
        recon = (_decoded[i] * 255).astype("uint8")
        output = np.hstack([original, recon])
        outputs = output if outputs is None else np.vstack([outputs, output])
    return outputs

# %%
EPOCHS = 50
INIT_LR = 1e-3
BS = 32
IMAGE_SIZE = (256, 256)
checkpoint_path = "training_1_100/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
print("[INFO] indexing file images BreaKHis dataset...")
using_magnification = '100X'
base_dataset = "binary_scenario"
class_dir = ['benign', 'malignant']
type_dataset = ['val', 'train']
dataset_train = []
dataset_val = []
for type_set in type_dataset:
    for class_item in class_dir:
        cur_dir = os.path.join(base_dataset, type_set, using_magnification ,class_item)
        for file in os.listdir(cur_dir):
            if type_set == 'train':
                dataset_train.append(os.path.join(cur_dir, file))
            else:
                dataset_val.append(os.path.join(cur_dir, file))
# Out:
# [INFO] indexing file images BreaKHis dataset...

# %%
print("[INFO] load images BreaKHis dataset...")
#  load images
train_images = []
val_images = []
for type_set in type_dataset:
    cur_dataset = dataset_train if type_set == 'train' else dataset_val
    for image_path in cur_dataset:
        if ".png" in image_path:
            image = cv2.imread(image_path)
            image = cv2.resize(image, IMAGE_SIZE)
            if type_set == 'train':
                train_images.append(image)
            else:
                val_images.append(image)
# Out:
# [INFO] load images BreaKHis dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
val_x = np.array(val_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
print("[INFO] building auto encoder...")
auto_encoder = ConvAutoEncoder.build(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor="val_loss",
    verbose = 1,
    mode='min',
    save_best_only=True)
auto_encoder.compile(loss="mse", optimizer=opt)
auto_encoder.summary()
# Out:
# [INFO] building auto encoder...
# Model: "auto_encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 128)     3584
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128, 128, 128)     0
# _________________________________________________________________
# enc_filter_128 (BatchNormali (None, 128, 128, 128)     512
# _________________________________________________________________
# flatten (Flatten)            (None, 2097152)           0
# _________________________________________________________________
# encoded (Dense)              (None, 48)                100663344
# _________________________________________________________________
# dense (Dense)                (None, 2097152)           102760448
# _________________________________________________________________
# reshape (Reshape)            (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 256, 256, 128)     147584
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256, 256, 128)     0
# _________________________________________________________________
# dec_filter_128 (BatchNormali (None, 256, 256, 128)     512
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 256, 256, 3)       3459
# _________________________________________________________________
# decoded (Activation)         (None, 256, 256, 3)       0
# =================================================================
# Total params: 203,579,443
# Trainable params: 203,578,931
# Non-trainable params: 512
# _________________________________________________________________

# %%
# train the convolutional auto encoder
print("[INFO] training auto encoder...")
H = auto_encoder.fit(
    train_x, train_x,
    shuffle=True,
    validation_data=(val_x, val_x),
    epochs=EPOCHS,
    callbacks = [checkpoint_callback],
    batch_size=BS)
# Out:
# [INFO] training auto encoder...
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0591
# Epoch 00001: val_loss improved from inf to 0.02074, saving model to training_1_100/cp.ckpt
# 53/53 [==============================] - 62s 1s/step - loss: 0.0591 - val_loss: 0.0207
# Epoch 2/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0210
# Epoch 00002: val_loss did not improve from 0.02074
# 53/53 [==============================] - 26s 483ms/step - loss: 0.0210 - val_loss: 0.0209
# Epoch 3/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0145
# Epoch 00003: val_loss did not improve from 0.02074
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0145 - val_loss: 0.0233
# Epoch 4/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0142
# Epoch 00004: val_loss did not improve from 0.02074
# 53/53 [==============================] - 27s 506ms/step - loss: 0.0142 - val_loss: 0.0257
# Epoch 5/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0140
# Epoch 00005: val_loss did not improve from 0.02074
# 53/53 [==============================] - 26s 493ms/step - loss: 0.0140 - val_loss: 0.0272
# Epoch 6/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0138
# Epoch 00006: val_loss did not improve from 0.02074
# 53/53 [==============================] - 26s 493ms/step - loss: 0.0138 - val_loss: 0.0258
# Epoch 7/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0137
# Epoch 00007: val_loss did not improve from 0.02074
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0137 - val_loss: 0.0247
# Epoch 8/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 00008: val_loss did not improve from 0.02074
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0135 - val_loss: 0.0243
# Epoch 9/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0135
# Epoch 00009: val_loss did not improve from 0.02074
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0135 - val_loss: 0.0233
# Epoch 10/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0134
# Epoch 00010: val_loss improved from 0.02074 to 0.01930, saving model to training_1_100/cp.ckpt
# 53/53 [==============================] - 62s 1s/step - loss: 0.0134 - val_loss: 0.0193
# Epoch 11/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0133
# Epoch 00011: val_loss improved from 0.01930 to 0.01631, saving model to training_1_100/cp.ckpt
# 53/53 [==============================] - 122s 2s/step - loss: 0.0133 - val_loss: 0.0163
# Epoch 12/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 00012: val_loss did not improve from 0.01631
# 53/53 [==============================] - 28s 519ms/step - loss: 0.0132 - val_loss: 0.0164
# Epoch 13/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0131
# Epoch 00013: val_loss improved from 0.01631 to 0.01467, saving model to training_1_100/cp.ckpt
# 53/53 [==============================] - 64s 1s/step - loss: 0.0131 - val_loss: 0.0147
# Epoch 14/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0132
# Epoch 00014: val_loss improved from 0.01467 to 0.01433, saving model to training_1_100/cp.ckpt
# 53/53 [==============================] - 67s 1s/step - loss: 0.0132 - val_loss: 0.0143
# Epoch 15/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 00015: val_loss did not improve from 0.01433
# 53/53 [==============================] - 27s 514ms/step - loss: 0.0130 - val_loss: 0.0178
# Epoch 16/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0129
# Epoch 00016: val_loss did not improve from 0.01433
# 53/53 [==============================] - 27s 508ms/step - loss: 0.0129 - val_loss: 0.0154
# Epoch 17/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0127
# Epoch 00017: val_loss did not improve from 0.01433
# 53/53 [==============================] - 26s 494ms/step - loss: 0.0127 - val_loss: 0.0155
# Epoch 18/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0126
# Epoch 00018: val_loss improved from 0.01433 to 0.01352, saving model to training_1_100/cp.ckpt
# 53/53 [==============================] - 64s 1s/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 19/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0125
# Epoch 00019: val_loss did not improve from 0.01352
# 53/53 [==============================] - 28s 521ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 20/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 00020: val_loss did not improve from 0.01352
# 53/53 [==============================] - 27s 509ms/step - loss: 0.0124 - val_loss: 0.0148
# Epoch 21/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0124
# Epoch 00021: val_loss did not improve from 0.01352
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 22/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0123
# Epoch 00022: val_loss did not improve from 0.01352
# 53/53 [==============================] - 27s 502ms/step - loss: 0.0123 - val_loss: 0.0143
# Epoch 23/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0120
# Epoch 00023: val_loss did not improve from 0.01352
# 53/53 [==============================] - 27s 506ms/step - loss: 0.0120 - val_loss: 0.0138
# Epoch 24/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0119
# Epoch 00024: val_loss improved from 0.01352 to 0.01345, saving model to training_1_100/cp.ckpt
# 53/53 [==============================] - 62s 1s/step - loss: 0.0119 - val_loss: 0.0135
# Epoch 25/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0117
# Epoch 00025: val_loss did not improve from 0.01345
# 53/53 [==============================] - 27s 516ms/step - loss: 0.0117 - val_loss: 0.0159
# Epoch 26/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0116
# Epoch 00026: val_loss did not improve from 0.01345
# 53/53 [==============================] - 27s 514ms/step - loss: 0.0116 - val_loss: 0.0136
# Epoch 27/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0115
# Epoch 00027: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0115 - val_loss: 0.0143
# Epoch 28/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0113
# Epoch 00028: val_loss did not improve from 0.01345
# 53/53 [==============================] - 27s 502ms/step - loss: 0.0113 - val_loss: 0.0175
# Epoch 29/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0109
# Epoch 00029: val_loss did not improve from 0.01345
# 53/53 [==============================] - 27s 505ms/step - loss: 0.0109 - val_loss: 0.0139
# Epoch 30/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0107
# Epoch 00030: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0107 - val_loss: 0.0138
# Epoch 31/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0104
# Epoch 00031: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0104 - val_loss: 0.0142
# Epoch 32/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0102
# Epoch 00032: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0102 - val_loss: 0.0142
# Epoch 33/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0101
# Epoch 00033: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0101 - val_loss: 0.0144
# Epoch 34/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0096
# Epoch 00034: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0096 - val_loss: 0.0140
# Epoch 35/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0091
# Epoch 00035: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0091 - val_loss: 0.0145
# Epoch 36/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 00036: val_loss did not improve from 0.01345
# 53/53 [==============================] - 27s 500ms/step - loss: 0.0089 - val_loss: 0.0147
# Epoch 37/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0089
# Epoch 00037: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0089 - val_loss: 0.0159
# Epoch 38/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0086
# Epoch 00038: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0086 - val_loss: 0.0150
# Epoch 39/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0080
# Epoch 00039: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0080 - val_loss: 0.0150
# Epoch 40/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0078
# Epoch 00040: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0078 - val_loss: 0.0165
# Epoch 41/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0075
# Epoch 00041: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0075 - val_loss: 0.0161
# Epoch 42/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0073
# Epoch 00042: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0073 - val_loss: 0.0161
# Epoch 43/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0071
# Epoch 00043: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0071 - val_loss: 0.0162
# Epoch 44/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0072
# Epoch 00044: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0072 - val_loss: 0.0157
# Epoch 45/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0068
# Epoch 00045: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 498ms/step - loss: 0.0068 - val_loss: 0.0163
# Epoch 46/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0062
# Epoch 00046: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 497ms/step - loss: 0.0062 - val_loss: 0.0164
# Epoch 47/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0059
# Epoch 00047: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 499ms/step - loss: 0.0059 - val_loss: 0.0160
# Epoch 48/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 00048: val_loss did not improve from 0.01345
# 53/53 [==============================] - 27s 500ms/step - loss: 0.0057 - val_loss: 0.0177
# Epoch 49/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0057
# Epoch 00049: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0057 - val_loss: 0.0159
# Epoch 50/50
# 53/53 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 00050: val_loss did not improve from 0.01345
# 53/53 [==============================] - 26s 500ms/step - loss: 0.0053 - val_loss: 0.0158

# %%
print("[INFO] making predictions...")
decoded = auto_encoder.predict(val_x)
vis = visualize_predictions(decoded, val_x)
image_example_path = "reconstruction"
cv2.imwrite(os.path.join(image_example_path,"recon_vis_100X_binary.png"), vis)
N = np.arange(0, EPOCHS)
plt.figure(figsize=(15,7))
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
# Out:
# [INFO] making predictions...

# %%
with open('training_1_100.json', 'w') as f:
    json.dump(H.history, f)

# %%
auto_encoder.save('training_1_100.h5')
